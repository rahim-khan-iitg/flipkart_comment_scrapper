# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs

# %%
link="https://www.youtube.com/watch?v=kTjuxyiQbfk"

# %%
api_key="AIzaSyDxQkZ1ik7V9uMZ4QaH3GQFcnIlySU2BBI"

# %%
from googleapiclient.discovery import build
youtube=build('youtube','v3',developerKey=api_key)
request=youtube.channels().list(part='statistics',forUsername='schafer5')
response=request.execute()
print(response)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'CQaLg93uHWVhAXsjXFUSX584w6A', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'zVioskyMmKJukBPA8zpX3ocmX4o', 'id': 'UCCezIgC97PvUuR4_gbFUs5g', 'statistics': {'viewCount': '85795222', 'subscriberCount': '1130000', 'hiddenSubscriberCount': False, 'videoCount': '232'}}]}

# %%
request=youtube.commentThreads().list(part='snippet',videoId='CTpzqNLjudk',maxResults=1000,textFormat='plainText')
response=request.execute()
next_token=response['nextPageToken']
response=response['items']
# for i in response:
#     print(i['snippet']['topLevelComment']['snippet']['textDisplay'])
print(response)
# Out:
# [{'kind': 'youtube#commentThread', 'etag': 'QpSPu9Em9FKoVJkq8CHACcZGNEs', 'id': 'Ugx8-I87cJRTVKkawtt4AaABAg', 'snippet': {'videoId': 'CTpzqNLjudk', 'topLevelComment': {'kind': 'youtube#comment', 'etag': '8np8gkuOejLuQCjr0pTCJECU1GM', 'id': 'Ugx8-I87cJRTVKkawtt4AaABAg', 'snippet': {'videoId': 'CTpzqNLjudk', 'textDisplay': 'Try this app for free, it will help you book trips when planning your travel:\xa0\nWeGo App: go.wego.com/40AIaGl', 'textOriginal': 'Try this app for free, it will help you book trips when planning your travel:\xa0\nWeGo App: go.wego.com/40AIaGl', 'authorDisplayName': 'Dhruv Rathee Vlogs', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqN-5SjIbuCS0gWHa1d8kpH0CYz6EVoSGvTl8ynZaQ=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCjNgqJ_FMLntYVzq7daw1TQ', 'authorChannelId': {'value': 'UCjNgqJ_FMLntYVzq7daw1TQ'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 162, 'publishedAt': '2023-05-28T14:09:06Z', 'updatedAt': '2023-05-
# ...

# %%
# for i in response:
#     print(i['snippet']['topLevelComment']['snippet']['authorDisplayName'])

# %%
# for i in response:
#     print(i)

# %%
new_data=youtube.commentThreads().list(part="snippet",videoId='CTpzqNLjudk',maxResults=100,pageToken=next_token)
response_next=new_data.execute()
print(response_next)
# Out:
# {'kind': 'youtube#commentThreadListResponse', 'etag': 'JUTmFBRr9ckxFFVHe02G9YM-sfI', 'nextPageToken': 'QURTSl9pM2xJSVVrbkNyRXhmaWJHX2d5TFN0ZWlrNzhfWV81SjV6SE05SWl3RmVqX0FCdVQxOGlFYnF6X2wtQVRkQk5Rdld4NV8xaEZLWjRLaWJ3RGt1RUo2MnFrS0JZ', 'pageInfo': {'totalResults': 99, 'resultsPerPage': 100}, 'items': [{'kind': 'youtube#commentThread', 'etag': 'jCu5fdge6x_02rVPhSuvOTybxIU', 'id': 'UgzsKgvqa-Gzzyp0I_R4AaABAg', 'snippet': {'videoId': 'CTpzqNLjudk', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'cCfd13T9ZOh9G2ZcPe6ll77WPCY', 'id': 'UgzsKgvqa-Gzzyp0I_R4AaABAg', 'snippet': {'videoId': 'CTpzqNLjudk', 'textDisplay': 'Ab main duniya ghum ke kya karu , ye to pura duniya ghum ke saab upload karne wala hai  😅', 'textOriginal': 'Ab main duniya ghum ke kya karu , ye to pura duniya ghum ke saab upload karne wala hai  😅', 'authorDisplayName': 'Aurum', 'authorProfileImageUrl': 'https://yt3.ggpht.com/X3y22a6HDDcaJrstJBIJ8eJoTia-POoLyKu3_ZmXe5v7s0kRu9gVBgvWk2CvTDAJHw7qeyHydQ=s48-c-k-c0x00ffffff-
# ...

# %%
for i in response_next['items']:
    print(i['snippet']['topLevelComment']['snippet']['textDisplay'])
# Out:
# Ab main duniya ghum ke kya karu , ye to pura duniya ghum ke saab upload karne wala hai  😅
# Barrier Reef are the best suitable place for nuclear testing.Why?
# Ye banda sub andhbhakto pelke jindegi ki maja loot raha he🤣🤣🤣
# Kitne paise milte hai bhai Propaganda faila ke
# Dhruv rathee❤
# Dhruv is god ❤
# You hate modi and now your enjoying your stay in Australia, the reason why you’re well respected in Australia is due to modi, not Khalistan whom your a great supporter of.
# I think your next trip will be in New Zealand🤔
# Which phone or camera you use to shoot the videos??
# Dhruv is a legend...
# एक तरफ Controversy हो रखी है दूसरी तरफ भाई मस्त है😅
# Speak bad defaming own country and enjoying life outside that is so shame.
# ❤😊
# Dhruv bhai best vlogger also❤
# Love you 💕 dhruv rathee sir
# 🗽🗽🗽🗽🗽🗽🗽🌹🌹
# Bhai kya reply tha hatts off Mr Education
# PELVISH WORD KYU BAND KAR RAKHA HE FHAAT GAYÌI KYAAS😂😂😂
# Funding aagyi😂😂
# Dhruv enjoy his life like every boy&#39;s dream life..🥺♥️
# ...

# %%
import numpy as np

# %%
np.fromstring('a,b,c',sep=',',dtype=chr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 np.fromstring('a,b,c',sep=',',dtype=chr)
#
# TypeError: Cannot interpret '<built-in function chr>' as a data type

# %%
np.fromstring("a b c",dtype=str,sep=' ')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 np.fromstring("a b c",dtype=str,sep=' ')
#
# ValueError: zero-valued itemsize
